# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from scipy import stats as st

# %%
from google.colab import drive #toimport google drive data

# %%
drive.mount('/content/drive') #to mount the drive data into colab clound and enterr the activation code
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/"My Drive/ML-Project"
# Out:
# /content/drive/My Drive/ML-Project

# %%
masterData = pd.read_csv('Backorder.csv')
masterData
# Out:
#          product_id  current_inventory  ...  rev_stop  went_on_backorder
# 0           1026827                0.0  ...        No                 No
# 1           1043384                2.0  ...        No                 No
# 2           1043696                2.0  ...        No                 No
# 3           1043852                7.0  ...        No                 No
# 4           1044048                8.0  ...        No                 No
# ...             ...                ...  ...       ...                ...
# 1687855     1407754                0.0  ...        No                 No
# 1687856     1373987               -1.0  ...        No                 No
# 1687857     1524346               -1.0  ...        No                Yes
# 1687858     1439563               62.0  ...        No                 No
# 1687859     1502009               19.0  ...        No                 No
#
# [1687860 rows x 17 columns]

# %%
masterData.info()

# %%
masterData = masterData.drop(['oe_constraint', 'rev_stop', 'source_has_issue'], axis = 1)

# %%
masterData.info()

# %%
subset_masterData = masterData.sample(5000)
sourceperf_corr_df = subset_masterData[['source_performance_6_months', 'source_performance_12_months']]
sourceperf_corr = sourceperf_corr_df.corr()
sourceperf_corr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d82f0a01acd5> in <module>()
# ----> 1 subset_masterData = masterData.sample(5000)
#       2 sourceperf_corr_df = subset_masterData[['source_performance_6_months', 'source_performance_12_months']]
#       3 sourceperf_corr = sourceperf_corr_df.corr()
#       4 sourceperf_corr
#
# NameError: name 'masterData' is not defined

# %%
corr_plot = sns.heatmap(sourceperf_corr, annot = True,cmap='viridis')

# %%
scattered_plot = sns.scatterplot('source_performance_6_months', 'source_performance_12_months', data = subset_masterData)
scattered_plot
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
masterData['went_on_backorder'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f638452c1708> in <module>()
# ----> 1 masterData['went_on_backorder'].value_counts()
#
# NameError: name 'masterData' is not defined
